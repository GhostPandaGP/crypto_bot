# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.arima_model import ARIMA

# %%
num = [10, 11, 12, 13]
columns = []
crypt = pd.DataFrame()
for i in num: 
    path = 'usd%d.csv' %i 
    frame = pd.read_csv(path, sep = ';') 
    crypt = pd.concat([frame, names])

# %%
print(crypt.shape)
crypt = crypt.drop_duplicates('Id')
print(crypt.shape)
# Out:
# (1500, 10)
# (1046, 10)

# %%
ETH = crypt[crypt.usd == 'USD-ETH'].reset_index()
LTC = crypt[crypt.usd == 'USD-LTC'].reset_index()
BTC = crypt[crypt.usd == 'USD-BTC'].reset_index()

# %%
ETH.Price.plot()
plt.show()

# %%
LTC.Price.plot()
plt.show()

# %%
BTC.Price.plot()
plt.show()

# %%
# модель
model = ARIMA(LTC.Price, order=(1,0,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                  Price   No. Observations:                  246
# Model:                     ARMA(1, 0)   Log Likelihood                  -3.762
# Method:                       css-mle   S.D. of innovations              0.244
# Date:                Thu, 27 Feb 2020   AIC                             13.525
# Time:                        09:35:26   BIC                             24.041
# Sample:                             0   HQIC                            17.759
#
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          60.6153      0.922     65.760      0.000      58.809      62.422
# ar.L1.Price     0.9862      0.009    106.924      0.000       0.968       1.004
#                                     Roots
# ...
#                   Real          Imaginary           Modulus         Frequency
# ...
